# %% [markdown]
# ### **Mini Project: web scrapping**
#
#
# Paris-Dauphine University
#
# * amenallah salem : amenallah.salem@dauphine.tn
# * aziz ben ammar : aziz.benammar@dauphine.tn
# * mohamed amine gaidi : mohamedamine.gaidi@dauphine.tn
# * Aouadni Amel : amel.aouadni@dauphine.tn

# %% [markdown]
#  **Install the Package :**

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in /home/amenallah/anaconda3/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /home/amenallah/anaconda3/lib/python3.7/site-packages (from bs4) (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in /home/amenallah/anaconda3/lib/python3.7/site-packages (from beautifulsoup4->bs4) (2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /home/amenallah/anaconda3/lib/python3.7/site-packages (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/amenallah/anaconda3/lib/python3.7/site-packages (from requests) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/amenallah/anaconda3/lib/python3.7/site-packages (from requests) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/amenallah/anaconda3/lib/python3.7/site-packages (from requests) (1.25.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/amenallah/anaconda3/lib/python3.7/site-packages (from requests) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **import required libs**

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# **Read the page at the specified URL:**

# %%
r =requests.get("https://boston.craigslist.org/search/sof")
r
# Out:
# <Response [200]>

# %%
# Print first 500 character
print(r.text[0:500])
# Out:
# ﻿<!DOCTYPE html>
# <html class="no-js"><head>
#     <title>boston software/qa/dba/etc  - craigslist</title>
#
#     <meta name="description" content="boston software/qa/dba/etc  - craigslist">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>
#     <link rel="canonical" href="https://boston.craigslist.org/search/sof">
#     <link rel="alternate" type="application/rss+xml" href="https://boston.craigslist.org/search/sof?format=rss" title="RSS feed for craigslist | boston software/qa/dba/etc  - craig

# %%
inf = reponse.text
inf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1d32ac7dd43a> in <module>
# ----> 1 inf = reponse.text
#       2 inf
#
# NameError: name 'reponse' is not defined

# %% [markdown]
# # **Parsing the HTML using BeatifulSoup**
# We're going to parse the HTML using the Beautiful Soup 4 library, which is a popular Python library for web scraping
#
# Beautiful Soup is reading the HTML and making sense of its structure

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %% [markdown]
# # **Extracting the URL:**

# %%
items=soup.find_all('a')

# %%
for item in items:
    print(item.get('href'))
# Out:
# https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile
# https://apps.apple.com/us/app/craigslist/id1336642410
# /
# /
# https://post.craigslist.org/c/bos
# https://accounts.craigslist.org/login/home
# #
# #
# /
# https://accounts.craigslist.org/login?rt=L&rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fboston%252Ecraigslist%252Eorg%252Fsearch%252Fsof
# /search/sof
# /search/sof
# /search/sof?sort=date&
# /search/sof
# /search/sof
#
# https://boston.craigslist.org/gbs/sof/d/waltham-become-certified-cloud/7114693082.html
# https://boston.craigslist.org/gbs/sof/d/waltham-become-certified-cloud/7114693082.html
# #
# https://boston.craigslist.org/gbs/sof/d/needham-heights-want-to-earn-15-hr/7113786538.html
# https://boston.craigslist.org/gbs/sof/d/needham-heights-want-to-earn-15-hr/7113786538.html
# #
# https://boston.craigslist.org/nos/sof/d/gloucester-data-management-coordinator/7112273528.html
# https://boston.craigslist.org/nos/sof/d/gloucester-data-management-coordinator/7112273528.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7111855189.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7111855189.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-billionare-backed-robotics/7111450732.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-billionare-backed-robotics/7111450732.html
# #
# https://boston.craigslist.org/nos/sof/d/gloucester-project-manager/7111316021.html
# https://boston.craigslist.org/nos/sof/d/gloucester-project-manager/7111316021.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7108163205.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7108163205.html
# #
# https://boston.craigslist.org/nos/sof/d/beverly-software-developer-for-new/7106067060.html
# https://boston.craigslist.org/nos/sof/d/beverly-software-developer-for-new/7106067060.html
# #
# https://boston.craigslist.org/gbs/sof/d/jupiter-sr-software-engineer-join/7105982492.html
# https://boston.craigslist.org/gbs/sof/d/jupiter-sr-software-engineer-join/7105982492.html
# #
# https://boston.craigslist.org/gbs/sof/d/jupiter-data-engineer-manager-join/7105982301.html
# https://boston.craigslist.org/gbs/sof/d/jupiter-data-engineer-manager-join/7105982301.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7104387624.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7104387624.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7101229136.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7101229136.html
# #
# https://boston.craigslist.org/sob/sof/d/hanover-co-founder-wanted-for-tech/7100922294.html
# https://boston.craigslist.org/sob/sof/d/hanover-co-founder-wanted-for-tech/7100922294.html
# #
# https://providence.craigslist.org/sof/d/riverside-looking-for-cobol-programmer/7104210642.html
# https://providence.craigslist.org/sof/d/riverside-looking-for-cobol-programmer/7104210642.html
# #
# https://capecod.craigslist.org/sof/d/woods-hole-data-management-coordinator/7111313095.html
# https://capecod.craigslist.org/sof/d/woods-hole-data-management-coordinator/7111313095.html
# #
# #page-top
# #page-top
# /search/sof
# /search/sof
#
# https://boston.craigslist.org/search/sof?format=rss
# https://www.craigslist.org/about/rss
# https://www.craigslist.org/about/help/
# https://www.craigslist.org/about/scams
# https://www.craigslist.org/about/privacy.policy
# https://forums.craigslist.org/?forumID=8
# https://www.craigslist.org/about/craigslist_is_hiring
# //www.craigslist.org/about/terms.of.use.en-us
# https://www.craigslist.org/about/

# %% [markdown]
# # **Extracting Titles:**
# In order to locate the titles, we can use its find() method to find a single tag that matches a specific pattern, in contrast to the find_all() method we used above to find all tags that match a pattern

# %%
titres =soup.find_all("a",{"class":"result-title"})

# %%
for titre in titres:
    print(titre.text)
# Out:
# Become a Certified Cloud Architect Professional
# Want to earn $15/hr? Apply to Restaurant Depot
# Data Management Coordinator
# Data Science Fellowship
# Billionare backed Robotics company- Engineer
# Project Manager
# Data Science Fellowship
# Software Developer for new startup (React, Python)
# Sr. Software Engineer - Join a THRIVING Company actively recruiting!!
# Data Engineer Manager- Join a THRIVING Company actively recruiting!!
# Data Science Fellowship
# Data Science Fellowship
# Co-founder wanted for tech business startup
# Looking For Cobol Programmer
# Data Management Coordinator

# %% [markdown]
# # **Extracting Adress:**

# %%
adresses= soup.find_all("span",{"class":"result-hood"})

# %% [markdown]
# # **Extracting Jobs:**

# %%
jbs=soup.find_all('p',{'class':'result-info'})

# %% [markdown]
# we extract the job title, location, date, link and job description

# %%
jb_num = 0
while True:
    
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data,'html.parser')
    jobs = soup.find_all('p',{'class':'result-info'})
    
    for job in jobs:
        titre = job.find('a',{'class':'result-title'}).text
        location_tag = job.find('span',{'class':'result-hood'})
        loc = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find('time', {'class': 'result-date'}).text
        lnk = job.find('a', {'class': 'result-title'}).get('href')
        r2 = requests.get(lnk)
        job_data = r2.text
        job_soup = BeautifulSoup(job_data, 'html.parser')
        job_desc = job_soup.find('section',{'id':'postingbody'}).text
        job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
        job_atr = job_attributes_tag.text if job_attributes_tag else "N/A"
        jb_num+=1
        print('Job Title:', titre, '\nLocation:', loc, '\nDate:', date, '\nLink:', lnk,"\n", job_atr, '\nJob Description:', job_desc,'\n---')
    url_tag = soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
        url= 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break
        
print("Total Jobs:", jb_num)
# Out:
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Apr 28
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7115401624.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Project Manager
# Location: boston: boston/cambridge/brookline
# Date: Apr 28
# Link: https://boston.craigslist.org/gbs/sof/d/boston-project-manager/7115313503.html
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Project Manager - Software - Billerica, MA - $120KThis software company offers a distributed automation framework providing life cycle management of integrated hardware and software solutions through an immersive user experience. They are made up of a team of engineers, user experience professionals, product managers, and more.They are seeking a strong Project Manager to work alongside the Head of Product, the VP of Engineering, and team members from their top customer. As a Project Manager your day to day will include interacting with architects and product owners on the customer side and working alongside your engineering team to provide insightful direction on software deliverables. As this company prepares to undertake one of their largest software deliverables to date, they are actively seeking qualified candidates.Experience Needed:5 + years of experience delivering software projects within an agile environmentHands on experience working with Jira and Git toolsAbility to thrive in a fast paced software startup environmentPrior experience as a Project Manager within a software product firmPluses:Prior experience in a professional services environment AND SaaS product environmentPrior experience working for digitally immersive and strong user experience based software companiesBenefits:Join a team committed to top tier software design and development standards100% paid for Health Insurance Equity planUnlimited PTORemote Friendly Office Love Nintendo? Our lounge is filled with old school video games for all to enjoy!Find Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: Become a Certified Cloud Architect Professional
# Location: N/A
# Date: Apr 27
# Link: https://boston.craigslist.org/gbs/sof/d/waltham-become-certified-cloud/7114693082.html
#
# compensation: 120000
#
# employment type: employee's choice
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Cloud Architects are in great demand worldwide, thus the AWS certification holds great value in today's job market.
#
# If you’re looking for an extra edge in landing a new job or promotion, cloud certification can be a great option. A lot of opportunities will open up: you can pursue career paths like AWS Solutions Architect, Cloud Developer, AWS Engineer, Cloud Systems Engineer, DevOps Engineer, Cloud Architect and AWS SysOps Admin among others. AWS training will help you grab this opportunity and accelerate your career.
#
# Why AWS?
#
# With the increasing focus on cloud computing and infrastructure over the last several years, cloud architects are in great demand worldwide. Many organizations have moved to cloud platforms for better scalability, mobility, and security, and cloud solutions architects are among the highest paid professionals in the IT industry. According to Forbes, enterprise IT architects with cloud computing expertise are earning a median salary of $137,957.
#
# Why ZiyoTek Institute of Technology?
#
# ZiyoTek is Accredited by Higher Learning Commission.
#
# No matter the stage of your cloud initiative, ZiyoTek can help every step of the way. AWS Certification Training from ZiyoTek is designed to provide in-depth knowledge about AWS architectural principles and its services. We offer structured AWS training with an updated curriculum as per current industry requirements and best practices. We have passionate AWS Instructors who not only have real-world experience, but also go through a rigorous process to validate their teaching expertise. The school offers personalized financial planning options.
#
# Are you ready to Jump-Start Your Career and Increase Your Salary ?
# ** Classes Begin on July 1, 2020 **
#
# If you would like to learn more about the program- Sign up for free Event hosted by experienced instructors, where you can learn a lot about the program. This session is MANDATORY if you are planning to sign up to our course.
#
# Sign up for Info Events: https://www.eventbrite.com/e/cloud-architect-program-info-session-boston-tickets-100427840374
#
# DATE AND TIME (Seats will fill up fast)
# Sat, May 30, 2020
# 10:30 AM – 12:30 PM CDT
#
# LOCATION:
# Online Webinar
#
#
# CONTACTS:
# Contact us at ziyotek@ziyotek.com
# Call us at 202-630-0504
# Visit us at ziyotek.com
#
# ---
# Job Title: Want to earn $15/hr? Apply to Restaurant Depot
# Location: Needham Heights
# Date: Apr 25
# Link: https://boston.craigslist.org/gbs/sof/d/needham-heights-want-to-earn-15-hr/7113786538.html
#  N/A
# Job Description:
#
# QR Code Link to This Post
#
#
# APPLY NOW
# Restaurant Depot Front End Supervisor PART-TIME OR FULL-TIME  $15/hr  114 1st Ave., Needham Heights, MA 02494 Ensures that product is properly loaded, rung up and processed accurately and timely as well as handling customer problems and issues to develop a spirit of positive customer service. Essential functions: • Supervises, trains, evaluates and works alongside cashiers, front-end loaders, checkers and U-boat retrieval • Ensures safe operating procedures are followed. • Makes recommendations for hiring, firing and promoting of employees. • Prevents long lines and delayed customer checkouts by anticipates busy times of each day, week and/or season and developing weekly schedules for cashiers and loaders including lunches and breaks. • As part of loss prevention, ensures all employees at registers are performing cart to cart transfers when processing sales. • Secures front end by making sure the loaders and cashiers do not exchange information on counts from the receipt. • Ensures that loaders are loading wagons and assisting customers to the parking lot. • Monitors loaders to make sure that they load all product and check any open boxes to ensure integrity/security of product being entered. • Ensures loaders are loading and conducting piece counts and calling off to supervisors. • Ensures that the front end has proper staffing and operating equipment to allow quick and accurate checkout. Including scanners and registers. • Ensures that cashiers are checking big boxes to ensure the integrity of the ring-up. • Ensures Front End Supervisor are checking all wagons at point of exit for proper date, name on top of receipt, number of receipt total of last receipt, and matches total on yellow paid receipt. • Reviews cashier and loader errors and documents in log, for them to sign. • Handles adjustments, returns, over rings, voids, etc. so as to maintain a smooth flow of customers. • Keeps logs of items not properly labeled to make sure they are corrected on floor. • Monitors cashiers to make sure they are following through on their job responsibilities concerning loading of goods onto wagons, checking of receipts and counts, as well as ringing/scanning of product. • Assures that customer problems are handled quickly so as not to allow the cashier or loader to have words with the customer. • Maintains dialogue with customers to get feedback on items not found, and quality of service on the floor. • Maintains a New Item Request log which is reviewed weekly with the Branch Manager. • Ensures that customers have adequate supply of wagons that are working and roll easy. • Makes sure that employees in front end are properly dressed and wearing their name tags. • Assigns employees in slow periods to do other work, such as return or processing of damages, sweeping and cleaning of F/E and parking lot area. • Ensures all supervisors are completing a minimum of 5 test checks per day they work. • Maintains integrity of F/E displays and stocking areas. • Ensure registers are stocked with the Rate US Cards, flyers, hot sheets, store maps, etc. Schedule - Shift start: 6:30AM or 9:00AM or 10:00AM - Shift length: 8.5 hours - Days: open flexibility is preferred  Benefits - Health, dental, vision insurance available after 90 days - Paid time off - 401k  Requirements - Previous retail experience dealing with customers and cashiers. - Must be at least 18+ years old - Must pass drug screen - Can lift 50 lbs  About Restaurant Depot Restaurant Depot is a Members-Only Wholesale Cash & Carry Foodservice Supplier. Their mission is to be your one-stop shop for savings, selection, and service, seven days a week. They have been supplying independent food businesses with quality products from large cash and carry warehouse stores since 1990. They became the leading low-cost alternative to other foodservice suppliers by eliminating the overhead of a traditional distributor, focusing on the needs of independent foodservice operators and offering free membership.
# APPLY NOW
# ---
# Job Title: Data Management Coordinator
# Location: Gloucester, MA
# Date: Apr 22
# Link: https://boston.craigslist.org/nos/sof/d/gloucester-data-management-coordinator/7112273528.html
#
# compensation: Commensurate with experience and qualifications.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Integrated Statistics is looking for a Data Management Coordinator to work with National Oceanic and Atmospheric Administration (NOAA) National Marine Fisheries Service (NMFS) Northeast Fisheries Science Center (NEFSC) and Greater Atlantic Regional Field Office (GARFO). The Data Management Coordinator will work directly with staff from GARFO, NEFSC, and the Atlantic Coastal Cooperative Statistics Program (ACCSP) on a database merger project that will incorporate state fisheries data into a single comprehensive database for all US commercial fisheries catch in the Northeast. The position may be located in either Gloucester, MA or Woods Hole, MA.
#
# Currently, NEFSC and GARFO have two parallel systems for catch monitoring and accounting, with the GARFO-led system focusing on quota monitoring and the NEFSC-led system supporting stock assessments and other research activities. The two systems each integrate data across a wide array of fishery information systems, and each approaches that integration slightly differently. Both systems require significant maintenance and upgrading as regulations and data streams change frequently. The Catch Accounting and Monitoring System (CAMS) implementation team is creating a single comprehensive database for all federal Northeast US fisheries catch.
#
# The Data Management Coordinator will work with the CAMS Project Manager and state natural resource managers to incorporate state data that is reported to ACCSP into CAMS. The Data Coordinator will also develop the technical specifications that ensure state data reporting to ACCSP is at a sufficient level of detail to allow incorporation in the CAMS database. The state data will remain housed at ACCSP, but will be linked to GARFO via relational database tables that integrate state fisheries-dependent data into CAMS.
#
# Duties
# The task includes but is not limited to these duties:
#
#     Coordinating the inclusion of state fisheries catch and effort data, including working with states to ensure their data reporting to ACCSP is at a sufficient level of detail to allow incorporation into the CAMS database.
#     Coordinating accurate, complete, and timely transfer of state level data from ACCSP to the CAMS database.
#     Working with the internal CAMS project team to develop a data management plan that outlines data capture, data flow, data queries, manual checks, and data listing to ensure data integrity.
#     Developing a process/method to ensure ACCSP’s Quality Assurance/Quality Control (QA/QC) program provides timely feedback and correction of state data that parallels GARFO’s QA/QC program in coordination with the CAMS project team.
#     Working with data scientists to develop data management and visualization tools, including gathering/defining user requirements and performing user testing.
#
# Qualifications and Skills
# The Data Management Coordinator must:
#
#     Demonstrate proficiency in designing, creating, and implementing Oracle database systems.
#     Possess strong programming and development skills using PL/SQL (package, procedures, functions, triggers) and batch coding skills.
#     Possess the ability to manage large datasets, query, extract, and organize data in useful ways to reduce performance related issues.
#     Have experience in code migration, database change management and data management in multiple environments and different stages of the development life cycle.
#     Possess experience with data backup, data recovery, data dictionaries, and data standardization processes.
#     Possess the ability to handle multiple projects and deadlines with flexibility between tasks.
#     Have a track record of ensuring performance, security, integrity, and availability of databases.
#     Be able to support application development through integrated project work group meetings, data modeling, code reviews, and system reviews for quality and performance.
#     Demonstrate ability to work with management and developers in providing quick resolutions during critical production issues with performance related resolutions.
#     Implement and integrate security standards set by the NOAA/NMFS/ Office of the Chief Information Officer (OCIO).
#     Possess excellent written and oral communication skills..
#
# The position is expected to last one year. The position can be located in either Gloucester MA or Woods Hole MA. There is a possibility for some remote work. The position is eligible for the pay and benefits described on the Integrated Statistics website. To apply for this position, go to https://jobs.intstats.com/JobDetails.jsp?jobListingId=256or visit www.integratedstatistics.com, click Employment Opportunities, click the job name and click the Apply Here link.
#
# Integrated Statistics is an equal opportunity employer and will not discriminate against any employee or applicant on the basis of age, color, disability, gender, national origin, race, religion, gender identity, sexual orientation, veteran status, or any classification protected by federal, state, or local law. Consistent with its obligations under federal law, Integrated Statistics is committed to taking affirmative action to employ and advance in employment qualified women, minorities, disabled individuals, special disabled veterans, veterans of the Vietnam era, and other eligible veterans. For assistance with accessibility of applications, posters, forms, and/or documents, please email the Integrated Statistics office.
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Apr 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7111855189.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Billionare backed Robotics company- Engineer
# Location: Boston
# Date: Apr 20
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-billionare-backed-robotics/7111450732.html
#
# compensation: Determined by market
#
# employment type: employee's choice
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Are you a robotics engineer or programmer?
#
# Do you get jazzed up about computers and artificial intelligence, and wish to be a part of cutting-edge technology?
#
# Then we have an exciting opportunity for you!
#
# Send us your contact information and resume to find out more now!
# ---
# Job Title: Project Manager
# Location: Gloucester, MA
# Date: Apr 20
# Link: https://boston.craigslist.org/nos/sof/d/gloucester-project-manager/7111316021.html
#
# compensation: Commensurate with experience and qualifications.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Integrated Statistics is looking for a Project Manager to work with National Oceanic and Atmospheric Administration (NOAA) National Marine Fisheries Service (NMFS) Northeast Fisheries Science Center (NEFSC) and Greater Atlantic Regional Field Office (GARFO). The Project Manager will work directly with staff from both GARFO and NEFSC on a database merger project. The position may be located in Gloucester or in Woods Hole, MA.
#
# Currently, NEFSC and GARFO have two parallel systems for catch monitoring and accounting, with the GARFO-led system focusing on quota monitoring and the NEFSC-led system supporting stock assessments and other research activities. The two systems each integrate data across a wide array of fishery information systems, and each approaches that integration slightly differently. Both systems require significant maintenance and upgrading as regulations and data streams change frequently. The Catch Accounting and Monitoring System (CAMS) implementation team is creating a single comprehensive database for all federal Northeast US fisheries catch.  The Project Manager will assist with the management of this effort.
#
# Duties
# The task includes but is not limited to these duties:
#
#     Assisting in the planning and execution of the CAMS project.
#     Along with project co-chairs, identifying and assigning tasks and delivery dates according to the implementation plan.
#     Tracking the completion of tasks identified in the implementation plan, and identifying potential challenges to the project schedule.
#     Organizing meetings with the CAMS project team in order to facilitate project completion and team unity.
#     Serving as a collaborative liaison between project team staff and steering committee.
#     Communicating a monthly high-level status report to the CAMS steering committee.
#     Working closely with GARFO and NEFSC project team staff to resolve disagreements and facilitate on-time task and project completion.
#     Organizing presentations and outreach related to CAMS effort.
#
# Qualifications and Skills
# The Project Manager must:
#
#     Possess demonstrated experience in leading a team of IT professionals, providing strong leadership, direction, organization, guidance, decision making and conflict resolution.
#     Demonstrate excellent verbal and written communication skills.
#     Possess demonstrated understanding of the design, creation, and development of database systems.
#     Possess experience in code migration, database change management, and data management in multiple environments and different stages of the development life cycle.
#     Be capable of working as part of a team.
#     Possess experience with project management tools such as Agile, JIRA, etc.
#
# The position is expected to be full-time for one year. The position may be located either in Gloucester or Woods Hole MA. The rate of pay will be commensurate with experience and qualifications, and the position is eligible for the pay and benefits described on the Integrated Statistics website. To apply for this position, go to https://jobs.intstats.com/JobDetails.jsp?jobListingId=255 or visit www.integratedstatistics.com, click Employment Opportunities, click the job name and click the Apply Here link.
#
# Integrated Statistics is an equal opportunity employer and will not discriminate against any employee or applicant on the basis of age, color, disability, gender, national origin, race, religion, gender identity, sexual orientation, veteran status, or any classification protected by federal, state, or local law. Consistent with its obligations under federal law, Integrated Statistics is committed to taking affirmative action to employ and advance in employment qualified women, minorities, disabled individuals, special disabled veterans, veterans of the Vietnam era, and other eligible veterans. For assistance with accessibility of applications, posters, forms, and/or documents, please email the Integrated Statistics office.
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Apr 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7108163205.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Software Developer for new startup (React, Python)
# Location: Beverly
# Date: Apr  9
# Link: https://boston.craigslist.org/nos/sof/d/beverly-software-developer-for-new/7106067060.html
#
# compensation: Work for equity, pay possible
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Software Developer with 2+ years of experience
#
# Stack:
# React JS frontend
# Python/Django rest framework backend
# MySQL DB
#
# TableBoost, Inc is a small startup based out of Beverly, MA.  The TableBoost app helps restaurants manage their facility.  We have a working app with several customers/restaurants.  Currently the development is done off-shore and we want to do it locally.  We are looking for a developer or two that can help us add features to the product as we grow the business.  We work remotely and meet in Beverly, MA once a week (but not since COVID-19).
#
# Visit: https://tableboost.com for more details on TableBoost.
#
# If you are interested in working for equity and getting in early on a new startup, please send in your resume.  We are a fast growing company and a member of the TiE Boston accelerator.
#
#
#
#
# ---
# Job Title: Sr. Software Engineer - Join a THRIVING Company actively recruiting!!
# Location: Jupiter
# Date: Apr  9
# Link: https://boston.craigslist.org/gbs/sof/d/jupiter-sr-software-engineer-join/7105982492.html
#
# compensation: Highly competitive base salary / Profit-Sharing bonus/ Health, Dental, Vision, Life and Disability Insurance, and 401K
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Are you a Senior Software Engineer concerned about your current employment status?  Come join a stable company, even in today’s environment.  Voloridge is a growing quantitative investment management company in South Florida, managing over $3B in assets with less than 3% turnover.  Our offices are located right along Florida's intercoastal waterway in Jupiter, FL. Jupiter is ranked as one of the top 15 happiest places to live. We have beaches, amazing restaurants, shopping and nightlife right at our doorstep.
#
# https://voloridge-investment-management.hiringthing.com/job/177060/senior-software-engineer
# ---
# Job Title: Data Engineer Manager- Join a THRIVING Company actively recruiting!!
# Location: Jupiter
# Date: Apr  9
# Link: https://boston.craigslist.org/gbs/sof/d/jupiter-data-engineer-manager-join/7105982301.html
#
# compensation: Highly competitive base salary / Profit-Sharing bonus/ Health, Dental, Vision, Life and Disability Insurance, and 401K
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Are you a Data Engineer Manager concerned about your current employment status?  Come join a stable company, even in today’s environment.  Voloridge is a growing quantitative investment management company in South Florida, managing over $3B in assets with less than 3% turnover.  Our offices are located right along Florida's intercoastal waterway in Jupiter, FL. Jupiter is ranked as one of the top 15 happiest places to live. We have beaches, amazing restaurants, shopping and nightlife right at our doorstep.
#
# https://voloridge-investment-management.hiringthing.com/job/143581/data-engineering-manager
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Apr  6
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7104387624.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Mar 30
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7101229136.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Co-founder wanted for tech business startup
# Location: South Shore / Cape
# Date: Mar 30
# Link: https://boston.craigslist.org/sob/sof/d/hanover-co-founder-wanted-for-tech/7100922294.html
#
# compensation: Equity Stake
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Co-founder wanted for tech business startup
#
# Are you a the savvy self starter looking to join/build a startup? Do you have high level skills which you feel under-compensated for, or feel you could be doing more with whether in your spare time or your sole venture? This may be the spot for you!
#
# The Company is in it's infancy, white boards and work flow charts along with extensive internal market research and my own experience. I am seeking specifically a partner who will compliment my shortcomings in the tech side of this venture. I have the vision, the drive, and the finances to fund the launch. The company is a software/HR/supplemental hiring company that will be web based to be used by companies such as Indeed, Careerbuilder and the U.S. government for candidates seeking employment/job surfing. It is designed to bridge a missing link within the hiring process for the private sector. The reason this gap exists is because of the lack the lack of skilled employees in today's market place among virtually all industries. The secondary function relates specifically to unemployment for the government. This platform is designed to save business' and the tax payers both time and huge sums of money. Preliminary numbers from within my industry assume 10-18k per year per company. Larger scale companies such as law and finance stand to save in excess of 30k annually as a result. Billable's for this company are to be generated first by ad traffic, and by annual subscription. With nearly 28 MILLION registered business' in the US, the market for this is very real, and the demand high. I personally struggle with what this problem would solve daily, and a lot of my colleagues agree we have a real problem.  Add to that the nearly 6 MILLION people (which by the way is VERY LOW historically) on unemployment and the vision suddenly transcends my wildest dreams for opportunity.  I'd be willing to explore other avenues of revenue generation outside of the ones I am currently aware of.
#
# I'm not paid to be a founder. Neither will I pay you. But you'll own part of the company, with the additional benefits of:
# 1) the excitement and satisfaction that comes with being a startup founder
# 2) the multitudes of priceless skills you'll develop that will be your asset forever
# 3) the gratification of building something from nothing, for your own company
# 4) the opportunity to work with and learn from super driven and talented people- whom we will choose together
# 5) the deep knowing every day that you're living your highest potential
#
# Qualifications:
# Preferred-Proficient - Advanced skills in coding and website design
# Preferred- Proficient - Advanced skills in App integration/development
# General understanding of google ad-words and Social Media Marketing
#
# The right candidate is:
# Independent
# Self-starter
# Highly motivated
# Willing to self-educate
# Willing to sign a NDA and Non-Compete
# Willing to work unpaid in exchange for equity stake
#
# The job description is vast, and admittedly not fully understood. A candidate looking to operate within a cube with constant direction will not find it here. You have an entrepreneurial drive, a passion for and full understanding of the vision, the ability to work just as well independently as well as part of a team. An understanding of where you are weak so that we can highlight them and ensure we get either 1) the support we need identified upfront, or 2) an area for us both to focus on and self-educate in order to move forward. The ideal candidate is available to commit a minimum 15+ hours per week from home with face to face meetings weekly. Equity stake is based on experience, and results which we will outline clearly.
#
# About me:
# Visionary
# Seasoned HR and Production and Hiring Manager
# Small startup experience (2 small companies non tech)
# Marketing and sales experience
# Currently employed- this is a side project for me, which I am looking to partner, burn the boats (Kudos if you're up on this reference) and go at this full time. In order for me to do that we need to establish a relationship, and a product with billable's.
#
# What you can expect from me/ this process.
#
# 1st interview - by phone. My goal is to gain an understanding about you and what you are looking for and answer the questions that I can for you at this point
# 2nd interview - by phone. My goal here will be to gain answers to questions from the first phone interview and set up an in-person interview
# 3rd interview -in Person. Our goal is to see if we click, maybe an activity. You can expect to get a glimpse of the vision and have some small tasks assigned to you as part of the interview process. You can expect to be presented with two documents. 1) a non-disclosure 2) a non-compete
# 4th interview- in person. Our goal will be to see if the spark is there, is there passion for this vision on your end and understand the core competencies we would have combined and where the shortfalls might be.
#
# At this point I expect to have a couple of candidates from which to review.
#
# Please promptly reply to this ad to set up a time for us to meet along with your resume, education/background, any relevant startup experience and availability to dedicate to this project.
#
# I look forward to speaking with and learning more about you!
#
# Nick
#
#
# ---
# Job Title: Looking For Cobol Programmer
# Location: N/A
# Date: Apr  6
# Link: https://providence.craigslist.org/sof/d/riverside-looking-for-cobol-programmer/7104210642.html
#
# compensation: negotiable
#
# employment type: employee's choice
#
# internship
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Looking for a experienced cobol programmer
# Part time, Full time and Contract positions available
#
#
# ---
# Job Title: Data Management Coordinator
# Location: N/A
# Date: Apr 20
# Link: https://capecod.craigslist.org/sof/d/woods-hole-data-management-coordinator/7111313095.html
#
# compensation: Commensurate with experience and qualifications.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Integrated Statistics is looking for a Data Management Coordinator to work with National Oceanic and Atmospheric Administration (NOAA) National Marine Fisheries Service (NMFS) Northeast Fisheries Science Center (NEFSC) and Greater Atlantic Regional Field Office (GARFO). The Data Management Coordinator will work directly with staff from GARFO, NEFSC, and the Atlantic Coastal Cooperative Statistics Program (ACCSP) on a database merger project that will incorporate state fisheries data into a single comprehensive database for all US commercial fisheries catch in the Northeast.
#
# This position may be located in Woods Hole, MA or in Gloucester, MA.
#
# Currently, NEFSC and GARFO have two parallel systems for catch monitoring and accounting, with the GARFO-led system focusing on quota monitoring and the NEFSC-led system supporting stock assessments and other research activities. The two systems each integrate data across a wide array of fishery information systems, and each approaches that integration slightly differently. Both systems require significant maintenance and upgrading as regulations and data streams change frequently. The Catch Accounting and Monitoring System (CAMS) implementation team is creating a single comprehensive database for all federal Northeast US fisheries catch.
#
# The Data Management Coordinator will work with the CAMS Project Manager and state natural resource managers to incorporate state data that is reported to ACCSP into CAMS. The Data Coordinator will also develop the technical specifications that ensure state data reporting to ACCSP is at a sufficient level of detail to allow incorporation in the CAMS database. The state data will remain housed at ACCSP, but will be linked to GARFO via relational database tables that integrate state fisheries-dependent data into CAMS.
#
# Duties
# The task includes but is not limited to these duties:
#
#     Coordinating the inclusion of state fisheries catch and effort data, including working with states to ensure their data reporting to ACCSP is at a sufficient level of detail to allow incorporation into the CAMS database.
#     Coordinating accurate, complete, and timely transfer of state level data from ACCSP to the CAMS database.
#     Working with the internal CAMS project team to develop a data management plan that outlines data capture, data flow, data queries, manual checks, and data listing to ensure data integrity.
#     Developing a process/method to ensure ACCSP’s Quality Assurance/Quality Control (QA/QC) program provides timely feedback and correction of state data that parallels GARFO’s QA/QC program in coordination with the CAMS project team.
#     Working with data scientists to develop data management and visualization tools, including gathering/defining user requirements and performing user testing.
#
# Qualifications and Skills
# The Data Management Coordinator must:
#
#     Demonstrate proficiency in designing, creating, and implementing Oracle database systems.
#     Possess strong programming and development skills using PL/SQL (package, procedures, functions, triggers) and batch coding skills.
#     Possess the ability to manage large datasets, query, extract, and organize data in useful ways to reduce performance related issues.
#     Have experience in code migration, database change management and data management in multiple environments and different stages of the development life cycle.
#     Possess experience with data backup, data recovery, data dictionaries, and data standardization processes.
#     Possess the ability to handle multiple projects and deadlines with flexibility between tasks.
#     Have a track record of ensuring performance, security, integrity, and availability of databases.
#     Be able to support application development through integrated project work group meetings, data modeling, code reviews, and system reviews for quality and performance.
#     Demonstrate ability to work with management and developers in providing quick resolutions during critical production issues with performance related resolutions.
#     Implement and integrate security standards set by the NOAA/NMFS/ Office of the Chief Information Officer (OCIO).
#     Possess excellent written and oral communication skills..
#
# The position is expected to last one year. The position can be located in either Gloucester MA or Woods Hole MA. There is a possibility for some remote work. The position is eligible for the pay and benefits described on the Integrated Statistics website. To apply for this position, go to https://jobs.intstats.com/JobDetails.jsp?jobListingId=256 or visit www.integratedstatistics.com, click Employment Opportunities, click the job name and click the Apply Here link.
#
# Integrated Statistics is an equal opportunity employer and will not discriminate against any employee or applicant on the basis of age, color, disability, gender, national origin, race, religion, gender identity, sexual orientation, veteran status, or any classification protected by federal, state, or local law. Consistent with its obligations under federal law, Integrated Statistics is committed to taking affirmative action to employ and advance in employment qualified women, minorities, disabled individuals, special disabled veterans, veterans of the Vietnam era, and other eligible veterans. For assistance with accessibility of applications, posters, forms, and/or documents, please email the Integrated Statistics office.
# ---
# Job Title: Tech Apprentice
# Location: N/A
# Date: Apr 28
# Link: https://hartford.craigslist.org/sof/d/hartford-tech-apprentice/7115538168.html
#
# compensation: Weekly compensation
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Tech Apprenticeships
#
# Entry Level Software Engineers – No Experience Required - FREE Online Coding Programs
#
# Woz U offers customized training programs to provide leading technology companies with well-trained technical talent. This year, our clients are seeking over 3,000 entry-level tech roles and they want to hire you without prior experience and cover the cost of your training!
#
# What Kind of Tech Careers?
#
# Software Application Development
# Cyber Security
# Data Science
# Network Engineering
# Infrastructure
# Quality Assurance Testing
# Selected applicants will design, analyze and build next-gen software systems, including business applications, enterprise software, middleware, and network control systems across a variety of industries, including finance, insurance, retail, healthcare, and government.
#
# With a wide range of clients from Fortune 500 companies to small businesses, we not only provide you with the skills needed to succeed through an employer-paid training program, but we also give you the opportunity to put those skills to use on projects that matter.
#
# What We Offer:
#
# Enterprise level development training
# A $200 biweekly stipend while in training
# Mentoring program and ongoing support
# Real world experience
# Placement at one of our client locations
# Join us and be part of the next generation of Tech!
#
#
# Requirements:
# Associates degree in STEM field required (No higher education permitted)
# Relocation ability required
#
# Interviews are starting now!
# UPDATED Resumes needed to be considered!
# ---
# Total Jobs: 18

# %% [markdown]
# # **Create DatarFame to put on it all Data**

# %%
 import pandas as pd

# %%
np_jobs = {}
jb_num = 0
while True:
    
    rp = requests.get(url)
    data = rp.text
    soup = BeautifulSoup(data,'html.parser')
    jobs = soup.find_all('p',{'class':'result-info'})
    
    for job in jobs:
        
        titre = job.find('a',{'class':'result-title'}).text
        location_tag = job.find('span',{'class':'result-hood'})
        loc = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find('time', {'class': 'result-date'}).text
        lnk = job.find('a', {'class': 'result-title'}).get('href')
        
        job_response = requests.get(lnk)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data, 'html.parser')
        job_desc = job_soup.find('section',{'id':'postingbody'}).text
        job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
        job_atr = job_attributes_tag.text if job_attributes_tag else "N/A"
        
        jb_num+=1
        np_jobs[jb_num] = [titre, loc, date, lnk, job_atr, job_desc]
        
        
    tg = soup.find('a',{'title':'next page'})
    if tg.get('href'):
        url= 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break
        
print("Total Jobs:", job_no)
# Out:
# Total Jobs: 18

# %%
df = pd.DataFrame.from_dict(np_jobs, orient = 'index', columns = ['Job Title','Location','Date', 'Link', 'Job Attributes', 'Job Description'])
df.head()
# Out:
#                                          Job Title  ...                                    Job Description
# 1                          Data Science Fellowship  ...  \n\nQR Code Link to This Post\n\n\nWhat is Pat...
# 2                                  Project Manager  ...  \n\nQR Code Link to This Post\n\n\nProject Man...
# 3  Become a Certified Cloud Architect Professional  ...  \n\nQR Code Link to This Post\n\n\nCloud Archi...
# 4   Want to earn $15/hr? Apply to Restaurant Depot  ...  \n\nQR Code Link to This Post\n\n\nAPPLY NOW\n...
# 5                      Data Management Coordinator  ...  \n\nQR Code Link to This Post\n\n\nIntegrated ...
#
# [5 rows x 6 columns]

# %% [markdown]
# # **create csv file**

# %%
df.to_csv('np_jobs.csv')

# %%
file=pd.read_csv('np_jobs.csv')

# %%
file
# Out:
#     Unnamed: 0                                          Job Title  \
# 0            1                       Information Security Analyst
# 1            2                        Electronic Services Floater
# 2            3                            Data Science Fellowship
# 3            4                          Product Management Fellow
# 4            5                        Software Engineering Fellow
# 5            6                              IT Security Architect
# 6            7                                 Software Developer
# 7            8                                   Business Analyst
# 8            9                           Senior Software Engineer
# 9           10  BA/QA(BUSINESS ANALYST/QUALITY ANALYST) TRAINI...
# 10          11               Rails Engineer - 2+ years exp wanted
# 11          12  Embedded Software Engineer for Musical Instrum...
# 12          13                         Production DevOps Engineer
# 13          14                VP Application Solution and Support
# 14          15               Project Manager and QA Person Wanted
# 15          16                               Senior Data Engineer
# 16          17                            Data Science Fellowship
# 17          18                          Product Management Fellow
# 18          19                        Software Engineering Fellow
# 19          20                    Software Development Engineer I
# 20          21  BA/QA(BUSINESS ANALYST/QUALITY ANALYST) TRAINI...
# 21          22  Looking for a product assistant with some comp...
# 22          23                                       Scrum Master
# 23          24                    Senior PHP Drupal Web Developer
# 24          25                                  Software Engineer
# 25          26  Firmware Engineer-Dynamic Team, 1-2 years expe...
# 26          27  Hybrid DevOps/Sysadmin/InfoSec Role (2 positions)
# 27          28                         Senior Full-stack Engineer
# 28          29                   Electronic Operations Specialist
# 29          30                       Back-End Developer/Java Lead
# ..         ...                                                ...
# 31          32                                   C++ Ubuntu Gtest
# 32          33               Senior Full Stack Software Developer
# 33          34  Full Stack Developer for Rapidly Growing Medic...
# 34          35                                        Arduino Wiz
# 35          36   Data Analyst - Live in PARADISE (Relo available)
# 36          37                            Data Science Fellowship
# 37          38                          Product Management Fellow
# 38          39                        Software Engineering Fellow
# 39          40           Database Specialist- TEMP! - $25-30/hour
# 40          41  BA/QA(BUSINESS ANALYST/QUALITY ANALYST) TRAINI...
# 41          42  Senior Cross-Enterprise Project Portfolio Analyst
# 42          43                       Information Security Analyst
# 43          44           Solutions Engineer - Fortune 500 Clients
# 44          45  A project management job for a web site (softw...
# 45          46                                  Software Engineer
# 46          47                  Tech Consultant / Rails Developer
# 47          48                                   Database Analyst
# 48          49                                Front-End Developer
# 49          50                                    Mobile Engineer
# 50          51                            Ruby on Rails Developer
# 51          52                  Software Engineers - Python or GO
# 52          53                         PHP XML Web Developer Work
# 53          54              Statistical Analyst- Data Engineering
# 54          55                                Electrical Engineer
# 55          56                                  Software Engineer
# 56          57                  Senior .Net Developer - Full time
# 57          58  BA/QA(BUSINESS ANALYST/QUALITY ANALYST) TRAINI...
# 58          59  Full Stack Developer for Rapidly Growing Medic...
# 59          60                          Node.js Software Engineer
# 60          61             Software 20/20  Kitchen Cabinet Design
#
#                               Location    Date  \
# 0                              Medford  Mar 13
# 1                              Medford  Mar 13
# 2                                  NaN  Mar 12
# 3                                  NaN  Mar 12
# 4                                  NaN  Mar 12
# 5                               Walham  Mar 12
# 6                            Cambridge  Mar 11
# 7                          Telecommute  Mar 11
# 8                            Lexington  Mar 11
# 9                           Boston, MA  Mar 11
# 10                              Boston  Mar  8
# 11                         Waltham, MA  Mar  8
# 12                          Boston, MA  Mar  8
# 13                              Walham  Mar  7
# 14                              Boston  Mar  7
# 15  Boston: Boston/Cambridge/Brookline  Mar  7
# 16                                 NaN  Mar  5
# 17                                 NaN  Mar  5
# 18                                 NaN  Mar  5
# 19                         Waltham, MA  Mar  4
# 20                          Boston, MA  Mar  4
# 21                              CARZUM  Mar  2
# 22                             Waltham  Feb 28
# 23                          Manchester  Feb 28
# 24                              Boston  Feb 27
# 25             20 Dan Road, Canton, MA  Feb 27
# 26                             Waltham  Feb 26
# 27                       Cambridge, MA  Feb 26
# 28                             Medford  Feb 26
# 29                      Auburndale, MA  Feb 25
# ..                                 ...     ...
# 31                              Boston  Feb 24
# 32                      Virginia Beach  Feb 22
# 33                                 NaN  Feb 22
# 34                                  DC  Feb 19
# 35                             Jupiter  Feb 19
# 36                                 NaN  Feb 19
# 37                                 NaN  Feb 19
# 38                                 NaN  Feb 19
# 39                              Boston  Feb 19
# 40                          Boston, MA  Feb 19
# 41                             Waltham  Feb 15
# 42                             Medford  Feb 15
# 43                       Cambridge, MA  Feb 15
# 44                       Wellesley, MA  Feb 14
# 45                           Cambridge  Feb 14
# 46                           Cambridge  Feb 14
# 47                           Billerica  Feb 14
# 48                             Waltham  Feb 13
# 49  Boston: Boston/Cambridge/Brookline  Feb 13
# 50  Boston: Boston/Cambridge/Brookline  Feb 13
# 51  Boston: Boston/Cambridge/Brookline  Feb 13
# 52                                 NaN  Feb 27
# 53                                 NaN  Feb 18
# 54                                 NaN  Feb 13
# 55                                 NaN  Mar  8
# 56                                 NaN  Mar  6
# 57                                 NaN  Feb 25
# 58                                 NaN  Feb 22
# 59                                 NaN  Feb 21
# 60                                 NaN  Feb 20
#
#                                                  Link  \
# 0   https://boston.craigslist.org/gbs/sof/d/inform...
# 1   https://boston.craigslist.org/gbs/sof/d/chestn...
# 2   https://boston.craigslist.org/gbs/sof/d/boston...
# 3   https://boston.craigslist.org/gbs/sof/d/boston...
# 4   https://boston.craigslist.org/gbs/sof/d/boston...
# 5   https://boston.craigslist.org/bmw/sof/d/waltha...
# 6   https://boston.craigslist.org/gbs/sof/d/somerv...
# 7   https://boston.craigslist.org/gbs/sof/d/cambri...
# 8   https://boston.craigslist.org/gbs/sof/d/lexing...
# 9   https://boston.craigslist.org/gbs/sof/d/ba-qab...
# 10  https://boston.craigslist.org/gbs/sof/d/boston...
# 11  https://boston.craigslist.org/bmw/sof/d/waltha...
# 12  https://boston.craigslist.org/gbs/sof/d/boston...
# 13  https://boston.craigslist.org/bmw/sof/d/waltha...
# 14  https://boston.craigslist.org/gbs/sof/d/boston...
# 15  https://boston.craigslist.org/gbs/sof/d/boston...
# 16  https://boston.craigslist.org/gbs/sof/d/boston...
# 17  https://boston.craigslist.org/gbs/sof/d/boston...
# 18  https://boston.craigslist.org/gbs/sof/d/boston...
# 19  https://boston.craigslist.org/bmw/sof/d/waltha...
# 20  https://boston.craigslist.org/gbs/sof/d/ba-qab...
# 21  https://boston.craigslist.org/sob/sof/d/whitma...
# 22  https://boston.craigslist.org/bmw/sof/d/waltha...
# 23  https://boston.craigslist.org/nwb/sof/d/manche...
# 24  https://boston.craigslist.org/gbs/sof/d/boston...
# 25  https://boston.craigslist.org/sob/sof/d/canton...
# 26  https://boston.craigslist.org/bmw/sof/d/waltha...
# 27  https://boston.craigslist.org/gbs/sof/d/cambri...
# 28  https://boston.craigslist.org/gbs/sof/d/chestn...
# 29  https://boston.craigslist.org/gbs/sof/d/waltha...
# ..                                                ...
# 31  https://boston.craigslist.org/gbs/sof/d/boston...
# 32  https://boston.craigslist.org/gbs/sof/d/virgin...
# 33  https://boston.craigslist.org/gbs/sof/d/boston...
# 34  https://boston.craigslist.org/gbs/sof/d/silver...
# 35  https://boston.craigslist.org/gbs/sof/d/jupite...
# 36  https://boston.craigslist.org/gbs/sof/d/boston...
# 37  https://boston.craigslist.org/gbs/sof/d/boston...
# 38  https://boston.craigslist.org/gbs/sof/d/boston...
# 39  https://boston.craigslist.org/gbs/sof/d/boston...
# 40  https://boston.craigslist.org/gbs/sof/d/ba-qab...
# 41  https://boston.craigslist.org/bmw/sof/d/waltha...
# 42  https://boston.craigslist.org/gbs/sof/d/inform...
# 43  https://boston.craigslist.org/gbs/sof/d/cambri...
# 44  https://boston.craigslist.org/bmw/sof/d/welles...
# 45  https://boston.craigslist.org/gbs/sof/d/cambri...
# 46  https://boston.craigslist.org/gbs/sof/d/cambri...
# 47  https://boston.craigslist.org/nwb/sof/d/north-...
# 48  https://boston.craigslist.org/bmw/sof/d/waltha...
# 49  https://boston.craigslist.org/gbs/sof/d/boston...
# 50  https://boston.craigslist.org/gbs/sof/d/boston...
# 51  https://boston.craigslist.org/gbs/sof/d/boston...
# 52  https://providence.craigslist.org/sof/d/php-xm...
# 53  https://providence.craigslist.org/sof/d/provid...
# 54  https://southcoast.craigslist.org/sof/d/attleb...
# 55  https://hartford.craigslist.org/sof/d/milford-...
# 56  https://hartford.craigslist.org/sof/d/windsor-...
# 57  https://hartford.craigslist.org/sof/d/hartford...
# 58  https://hartford.craigslist.org/sof/d/hartford...
# 59  https://hartford.craigslist.org/sof/d/hartford...
# 60  https://hartford.craigslist.org/sof/d/east-ber...
#
#                                        Job Attributes  \
# 0   \ncompensation: Commensurate with Experience.\...
# 1   \ncompensation: Commensurate with Experience.\...
# 2   \ncompensation: 80,000-160,000\n\nemployment t...
# 3   \ncompensation: 80,000-160,000\n\nemployment t...
# 4   \ncompensation: 80,000-160,000\n\nemployment t...
# 5   \ncompensation: Commensurate with experience.\...
# 6   \ncompensation: tbd\n\nemployment type: full-t...
# 7   \ncompensation: TBD - Depending on experience\...
# 8                                                 NaN
# 9   \ncompensation: DOE\n\nemployment type: contra...
# 10  \ncompensation: $110,000 +bonus\n\nemployment ...
# 11  \ncompensation: negotiable\n\nemployment type:...
# 12  \ncompensation: competitive\n\nemployment type...
# 13  \ncompensation: Commensurate with experience.\...
# 14  \ncompensation: Starting rate $15/hr\n\nemploy...
# 15                                                NaN
# 16  \ncompensation: 80,000-160,000\n\nemployment t...
# 17  \ncompensation: 80,000-160,000\n\nemployment t...
# 18  \ncompensation: 80,000-160,000\n\nemployment t...
# 19  \ncompensation: DOE + benefits\n\nemployment t...
# 20  \ncompensation: DOE\n\nemployment type: contra...
# 21  \ncompensation: starting entry level base sala...
# 22  \ncompensation: Commensurate with experience.\...
# 23  \ncompensation: Competitive Compensation based...
# 24  \ncompensation: $65915/year\n\nemployment type...
# 25  \ncompensation: $70,000 - $80,000\n\nemploymen...
# 26  \ncompensation: Highly competitive salary + he...
# 27  \ncompensation: Commensurate with experience\n...
# 28  \ncompensation: Commensurate with Experience.\...
# 29  \ncompensation: DOE\n\nemployment type: full-t...
# ..                                                ...
# 31  \ncompensation: 100/hr\n\nemployment type: con...
# 32  \ncompensation: DOE\n\nemployment type: full-t...
# 33  \ncompensation: TBD\n\nemployment type: contra...
# 34  \ncompensation: you've seen the link, name you...
# 35  \ncompensation: Competitive Pay\n\nemployment ...
# 36  \ncompensation: 80,000-160,000\n\nemployment t...
# 37  \ncompensation: 80,000-160,000\n\nemployment t...
# 38  \ncompensation: 80,000-160,000\n\nemployment t...
# 39  \ncompensation: $25-30 per hour\n\nemployment ...
# 40  \ncompensation: DOE\n\nemployment type: contra...
# 41  \ncompensation: Commensurate with experience.\...
# 42  \ncompensation: Commensurate with Experience.\...
# 43  \ncompensation: tbd\n\nemployment type: full-t...
# 44  \ncompensation: $20 per hour\n\nemployment typ...
# 45  \ncompensation: $80,000 - $120,000 depending o...
# 46  \ncompensation: Competitive with 2-3 years exp...
# 47  \ncompensation: DOE\n\nemployment type: full-t...
# 48  \ncompensation: Commensurate with experience.\...
# 49                   \nemployment type: full-time\n\n
# 50  \ncompensation: Up to US$140000 per year\n\nem...
# 51  \ncompensation: US$70000 - US$150000 per year\...
# 52  \ncompensation: negotiable\n\nemployment type:...
# 53  \ncompensation: To: $55.00 per hour\n\nemploym...
# 54  \ncompensation: based on experience\n\nemploym...
# 55  \ncompensation: 110-120K\n\nemployment type: f...
# 56  \ncompensation: Negotiable\n\nemployment type:...
# 57  \ncompensation: DOE\n\nemployment type: contra...
# 58  \ncompensation: TBD\n\nemployment type: contra...
# 59  \ncompensation: Competitive, DOE\n\nemployment...
# 60  \ncompensation: To be discussed, based on expe...
#
#                                       Job Description
# 0   \n\nQR Code Link to This Post\n\n\nFounded loc...
# 1   \n\nQR Code Link to This Post\n\n\nFounded loc...
# 2   \n\nQR Code Link to This Post\n\n\nWhat is Pat...
# 3   \n\nQR Code Link to This Post\n\n\nWhat is Pat...
# 4   \n\nQR Code Link to This Post\n\n\nWhat is Pat...
# 5   \n\nQR Code Link to This Post\n\n\n\nAre you p...
# 6   \n\nQR Code Link to This Post\n\n\nHSRI, a mis...
# 7   \n\nQR Code Link to This Post\n\n\nSteepRock i...
# 8   \n\nQR Code Link to This Post\n\n\nSenior Soft...
# 9   \n\nQR Code Link to This Post\n\n\nBA/QA(BUSIN...
# 10  \n\nQR Code Link to This Post\n\n\n\n\nOur cli...
# 11  \n\nQR Code Link to This Post\n\n\nWe have an ...
# 12  \n\nQR Code Link to This Post\n\n\nCompany Des...
# 13  \n\nQR Code Link to This Post\n\n\n\nWe are se...
# 14  \n\nQR Code Link to This Post\n\n\nWe are a me...
# 15  \n\nQR Code Link to This Post\n\n\nSenior Data...
# 16  \n\nQR Code Link to This Post\n\n\nWhat is Pat...
# 17  \n\nQR Code Link to This Post\n\n\nWhat is Pat...
# 18  \n\nQR Code Link to This Post\n\n\nWhat is Pat...
# 19  \n\nQR Code Link to This Post\n\n\nYardi Syste...
# 20  \n\nQR Code Link to This Post\n\n\nBA/QA(BUSIN...
# 21  \n\nQR Code Link to This Post\n\n\nThis is a v...
# 22  \n\nQR Code Link to This Post\n\n\n\nDo you ha...
# 23  \n\nQR Code Link to This Post\n\n\nAre you rea...
# 24  \n\nQR Code Link to This Post\n\n\nSoftware En...
# 25  \n\nQR Code Link to This Post\n\n\nCopley Cont...
# 26  \n\nQR Code Link to This Post\n\n\nWe're an es...
# 27  \n\nQR Code Link to This Post\n\n\nApply here:...
# 28  \n\nQR Code Link to This Post\n\n\nFounded loc...
# 29  \n\nQR Code Link to This Post\n\n\n\nWant to w...
# ..                                                ...
# 31  \n\nQR Code Link to This Post\n\n\nThe project...
# 32  \n\nQR Code Link to This Post\n\n\nCan you per...
# 33  \n\nQR Code Link to This Post\n\n\nWe are a fo...
# 34  \n\nQR Code Link to This Post\n\n\nLooking for...
# 35  \n\nQR Code Link to This Post\n\n\nAre you a D...
# 36  \n\nQR Code Link to This Post\n\n\nWhat is Pat...
# 37  \n\nQR Code Link to This Post\n\n\nWhat is Pat...
# 38  \n\nQR Code Link to This Post\n\n\nWhat is Pat...
# 39  \n\nQR Code Link to This Post\n\n\nSummary \n\...
# 40  \n\nQR Code Link to This Post\n\n\nBA/QA(BUSIN...
# 41  \n\nQR Code Link to This Post\n\n\n\nAt the in...
# 42  \n\nQR Code Link to This Post\n\n\nFounded loc...
# 43  \n\nQR Code Link to This Post\n\n\nPlease Appl...
# 44  \n\nQR Code Link to This Post\n\n\nGene Town B...
# 45  \n\nQR Code Link to This Post\n\n\nGhamut invi...
# 46  \n\nQR Code Link to This Post\n\n\nhttps://the...
# 47  \n\nQR Code Link to This Post\n\n\nEmpire Tele...
# 48  \n\nQR Code Link to This Post\n\n\n\nAre you p...
# 49  \n\nQR Code Link to This Post\n\n\nMobile Deve...
# 50  \n\nQR Code Link to This Post\n\n\nRuby on Rai...
# 51  \n\nQR Code Link to This Post\n\n\nSoftware De...
# 52  \n\nQR Code Link to This Post\n\n\nRI Web base...
# 53  \n\nQR Code Link to This Post\n\n\n1 year cont...
# 54  \n\nQR Code Link to This Post\n\n\nPatrolPC, a...
# 55  \n\nQR Code Link to This Post\n\n\nImmediate h...
# 56  \n\nQR Code Link to This Post\n\n\nWe are look...
# 57  \n\nQR Code Link to This Post\n\n\nBA/QA(BUSIN...
# 58  \n\nQR Code Link to This Post\n\n\nWe are a fo...
# 59  \n\nQR Code Link to This Post\n\n\nJoin a smal...
# 60  \n\nQR Code Link to This Post\n\n\nGalleria Dr...
#
# [61 rows x 7 columns]
